# %% [markdown]
# Todo List Features:
# - input task
# - task edit
# - task delete
# - schedule due date
# - schedule time
# - list catetogies

# %%
# Initialize the to-do list dictionary
todo_list = {}

# Function to add a task with details
def add_task():
    task_id = len(todo_list) + 1
    task = input("Enter the task description (e.g., 'Finish homework'): ")
    category = 'School'
    due_date = '2024-09-30'
    due_time = '18:00'
    # category = input("Enter the category (e.g., 'School', 'Work', 'Personal'): ")
    # due_date = input("Enter the due date (in the format YYYY-MM-DD, e.g., '2024-09-30'): ")
    # due_time = input("Enter the due time (in the format HH:MM, e.g., '18:00'): ")
    todo_list[task_id] = {'task': task, 'category': category, 'due_date': due_date, 'due_time': due_time}
    print(todo_list)
    print(f"Task {task_id} added successfully.")

# Function to edit an existing task
def edit_task():
    task_id = int(input("Enter the task ID to edit: "))
    if task_id in todo_list:
        task = input("Enter the new task description (e.g., 'Finish homework'): ")
        category = input("Enter the new category (e.g., 'School', 'Work', 'Personal'): ")
        due_date = input("Enter the new due date (in the format YYYY-MM-DD, e.g., '2024-09-30'): ")
        due_time = input("Enter the new due time (in the format HH:MM, e.g., '18:00'): ")
        todo_list[task_id] = {'task': task, 'category': category, 'due_date': due_date, 'due_time': due_time}
        print(f"Task {task_id} updated successfully.")
    else:
        print("Task ID not found.")

# Function to delete a task
def delete_task():
    task_id = int(input("Enter the task ID to delete: "))
    if task_id in todo_list:
        del todo_list[task_id]
        print(f"Task {task_id} deleted successfully.")
    else:
        print("Task ID not found.")

# Function to display all tasks
def view_tasks():
    if todo_list:
        print("\n--- Your To-Do List ---")
        for task_id, details in todo_list.items():
            print(f"ID: {task_id} | Task: {details['task']} | Category: {details['category']} | Due: {details['due_date']} {details['due_time']}")
    else:
        print("No tasks available.")

# Function to view tasks by category
def view_tasks_by_category():
    category = input("Enter the category to filter tasks (e.g., 'School', 'Work', 'Personal'): ")
    filtered_tasks = {k: v for k, v in todo_list.items() if v['category'].lower() == category.lower()}
    if filtered_tasks:
        print(f"\n--- Tasks in Category '{category}' ---")
        for task_id, details in filtered_tasks.items():
            print(f"ID: {task_id} | Task: {details['task']} | Due: {details['due_date']} {details['due_time']}")
    else:
        print(f"No tasks found in category '{category}'.")

# Main Program Execution
while True:
    print("\nTo-Do List Menu:")
    print("1. Add Task")
    print("2. Edit Task")
    print("3. Delete Task")
    print("4. View All Tasks")
    print("5. View Tasks by Category")
    print("6. Exit")
    choice = input("Enter your choice (1-6): ")

    if choice == '1':
        add_task()
    elif choice == '2':
        edit_task()
    elif choice == '3':
        delete_task()
    elif choice == '4':
        view_tasks()
    elif choice == '5':
        view_tasks_by_category()
    elif choice == '6':
        print("Exiting To-Do List program.")
        break
    else:
        print("Invalid choice, please select a number between 1 and 6.")
# Out:
# To-Do List Menu:
# 1. Add Task
# 2. Edit Task
# 3. Delete Task
# 4. View All Tasks
# 5. View Tasks by Category
# 6. Exit
# Invalid choice, please select a number between 1 and 6.
#
# To-Do List Menu:
# 1. Add Task
# 2. Edit Task
# 3. Delete Task
# 4. View All Tasks
# 5. View Tasks by Category
# 6. Exit
# {1: {'task': '1', 'category': 'School', 'due_date': '2024-09-30', 'due_time': '18:00'}}
# Task 1 added successfully.
#
# To-Do List Menu:
# 1. Add Task
# 2. Edit Task
# 3. Delete Task
# 4. View All Tasks
# 5. View Tasks by Category
# 6. Exit
